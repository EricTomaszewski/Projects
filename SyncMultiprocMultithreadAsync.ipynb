# %%
# THIS CELL IS OBSOLETE AND REPLACED WITH custom_timer.py
# IN THE SAME FOLDER
# TO BE ABLE TO IMPORT IT IN THE NEXT CELLS

# TIMER MODULE

import timeit

def custom_timer(number, repeat):
    def wrapper(func):
        runs = timeit.repeat(func, number=number, repeat=repeat)
        print(sum(runs) / len(runs))
        
    return wrapper

# %%
# SYNCHRONOUS

from custom_timer import custom_timer

URL = 'https://httpbin.org/uuid'


def fetch(session, url):
    with session.get(url) as response:
        print(response.json()['uuid'])
        

@custom_timer(1,1)
def main():
    with requests.Session() as session:
        for _ in range(100):
            fetch(session, URL)
# Out:
# 97576bd9-3ccf-4674-8344-d9bae1ea2062
# 4b0778fb-8c0b-47f2-9cdd-dadf3ac73726
# 018ac939-7a0d-4779-bc0d-a8b0ea5c95f6
# 6e563c51-4362-4f1c-83d8-ccc97799c4e8
# d864d0a4-b4d5-400c-93f3-0531a1e1eb48
# c31f0ca1-2f2f-4ee6-9f43-7fc5f0d8e10f
# 115f0f84-e7e2-4bc5-add5-7eb097c4bd2e
# 8b16c5b9-0f38-4d7b-bdd2-8632cdaf1062
# d285add0-b73b-41e8-a150-3822a998b622
# 43973998-e97d-47c3-8b0d-2bf43dbcde44
# 45f0aa0d-6268-437a-9886-9503930aa045
# cc3da25f-b7db-40a9-9864-adc509a4703b
# 3a8e4933-00a3-416d-932e-8885a5591992
# 84cb478a-bcd3-4ca9-abcc-505c9ff84d1e
# 11effdc8-2108-4f66-9511-2213214baa42
# 058602de-2a51-419a-8fe7-733d68367497
# e3923b7c-3725-4860-ad55-afbb5bb55305
# f4b32143-c449-4894-aa63-a4484a5a5e61
# c2fbfec6-b90d-451b-a5d1-eaed928b526c
# a1e1b5a2-aa20-45b9-be0d-851889f3d73e
# 281240e5-b5e6-4be6-9c16-d458ab6ed7d1
# dc23df39-abef-4571-b14c-1d679ee90aab
# f558799a-ef00-45b3-8a3b-424d9fd91e65
# c77473c2-cd7e-4217-8f45-79817e4de380
# 9ac00323-0ea4-499a-9ec3-9a93afdb31cf
# 5522401e-c619-4743-88b8-eb011bdba3a8

# %%
# MULTI-PROCESSING

from multiprocessing.pool import Pool

import requests

from custom_timer import custom_timer

URL = 'https://httpbin.org/uuid'


def fetch(session, url):
    with session.get(url) as response:
        print(response.json()['uuid'])
        

@custom_timer(1,1)
def main():
    with Pool() as pool:
        with requests.Session() as session:
            pool.starmap(fetch, [(session, URL) for _ in range(100)])

# %%
# MULTI-THREADING
# thread is a segment of a process
# GIL - Global Interpreter Lock

from concurrent.futures import ThreadPoolExecutor

import requests

from custom_timer import custom_timer

URL = 'https://httpbin.org/uuid'


def fetch(session, url):
    with session.get(url) as response:
        print(response.json()['uuid'])
        

@custom_timer(1,1)            # changing the second argument is going to get the average
def main():
    with ThreadPoolExecutor(max_workers=10) as executor:        # changing number of workers speeds it up
        with requests.Session() as session:
            executor.map(fetch, [session] * 100, [URL] * 100)
# 8e3ea7fd-b6c4-4e4a-98a4-e151a5ecbd1f
# ba291af6-6955-4daa-8eac-10bd4020ae6d
# ef68979d-5ee8-4874-8861-7eb8a0ea0e19
# 58b8e66a-66da-4417-a0eb-8b7618c48f1c
# 4e253fb6-3237-4c59-a325-8ae89cf47cb1
# 9d366960-c0af-4471-9894-00847a0f1af3
# 390dc4bd-978e-4735-af56-f7c2688577a8
# d1a6380c-4dfd-499e-b092-b89a4f43e7ec
# 17b63f02-3aef-4a4d-849e-968ca3ca8f0a
# 2e789f3f-0164-4659-9ba3-f13528f430f4
# 7e19f35a-abbf-438a-8b25-d133a6df6f7c
# f5f30040-7416-4844-88e8-690ad59554f2
# 0fcb89ce-492b-453b-a4da-a6298c84ff5e
# 7b543198-18db-412d-9719-0ef1fd1fa07b
# cdcd9e1f-28f1-47e2-b71b-2e39631892a2
# 15a76232-5784-4658-96a2-cea1d3327203
# b6448029-f8c9-45c6-94e4-3180819456ce
# c8b3e526-a94b-4ed8-867e-72fc06706d04
# 69b4973a-7b53-4c10-b772-552abd12a449
# ff6e51b7-cd01-470a-b077-62e12262585b
# fb8b45e5-eac2-4ad2-a077-8d369a6d7d54
# 326d0056-8815-4901-8693-51b1b30a8b82
# 2d6b2d57-e353-4c42-8c8d-2b32c4056dcb
# 9d473a95-c7ba-48b2-b9ff-fea361a10d1d
# 001b8b83-d631-4e0e-a4ed-fb1eb035d8fb
# ea718d03-410a-4b92-a63c-440f5a36f810
# fce01a66-0cce-4171-bae5-8d365f03cd16
# dda6dab7-94ab-4953-b8ac-11ee34fb4c74
# 794ce4e9-3e09-4076-9726-ca938b8656d4
# d268073f-d854-40bd-836e-c8915512f8e9
# 805fdcc8-df9a-4f55-a19c-67ff84be655b
# 05377ee3-7ed0-410d-abfd-0cac106ae5de
# 08fa74cc-39b8-4ca6-bf58-97c4995b2bdd
# f472d31f-acb0-4010-9788-7ccbfd08a848
# b5c28503-4a8b-400b-a991-ba06f68006f7
# e8ba8ceb-a5da-4704-8864-67a13e948c9f
# 21e8d091-e618-4c55-a4a9-f0c9a1cad118
# 463664cd-1587-4c0c-934b-851533342b01
# cfa50f1d-c5b8-46bc-8962-ae31759b5ba2
# 388320ee-6d40-453f-b548-b29ae09547cd
# 6b629aae-8ed6-4fdb-88b3-81d11df5ea10
# e5b1a7b3-96f8-4c38-8fc4-e1e07de4c8bf
# 128.9280251999735

# %%
# ASYNCIO
# differences from MULTI-THREADING
# it uses a single thread
# it is your code that decides what executres

# pip install aiohttp    ===>>> FIRST THING


import aiohttp

from custom_timer import custom_timer

URL = 'https://httpbin.org/uuid'


async def fetch(session, url):
    async with session.get(url) as response:
        json_response = await response.json()
        print(json_response['uuid'])
        


def main():
    async with aiohttp.ClientSession() as session:
        tasks = [fetch(session, URL) for _ in range(100)]
        await asyncio.gather(*tasks)


@custom_timer(1,1)      
def func():
    asyncio.run(main())
